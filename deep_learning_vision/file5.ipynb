# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# 데이터 준비
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data() # MNIST: 필기 숫자 데이터셋
x_train = x_train.reshape(60000, 784) # 1차원 구조로 변환
x_test = x_test.reshape(10000, 784) # 1차원 구조로 변환
x_train = x_train.astype(np.float32)/255.0 # [0,1]로 정규화
x_test = x_test.astype(np.float32)/255.0 # [0,1]로 정규화
y_train = tf.keras.utils.to_categorical(y_train, 10) # 원핫 코드로 변환
y_test = tf.keras.utils.to_categorical(y_test, 10) # 원핫 코드로 변환

# %%
# 모델 선택(신경망 구조 설계)
dmlp = Sequential()
dmlp.add(Dense(units=1024, activation="relu", input_shape=(784,))) # 은닉층 노드 개수 1024 / 은닉층 활성 함수 relu / 입력층 모양
dmlp.add(Dense(units=512, activation="relu")) # 은닉층 노드 개수 512 / 은닉층 활성 함수 relu
dmlp.add(Dense(units=512, activation="relu")) # 은닉층 노드 개수 512 / 은닉층 활성 함수 relu
dmlp.add(Dense(units=10, activation="softmax")) # 출력층 노드 개수 10 / 출력층 활성 함수 softmax
# Out:
# c:\Users\GreenTea\anaconda3\envs\Test\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 학습
dmlp.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.0001), metrics=["accuracy"]) # CE 손실 함수 / Adam 옵티마이저 / 학습률 / 평가지표:정확도
hist = dmlp.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test), verbose=2) # 훈련 집합 / 미니 배치 크기 / 훈련횟수 / 검증 집합
# Out:
# Epoch 1/50
# 469/469 - 13s - 27ms/step - accuracy: 0.8944 - loss: 0.4067 - val_accuracy: 0.9500 - val_loss: 0.1709
# Epoch 2/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9564 - loss: 0.1470 - val_accuracy: 0.9616 - val_loss: 0.1235
# Epoch 3/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9717 - loss: 0.0986 - val_accuracy: 0.9728 - val_loss: 0.0935
# Epoch 4/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9787 - loss: 0.0715 - val_accuracy: 0.9714 - val_loss: 0.0903
# Epoch 5/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9843 - loss: 0.0540 - val_accuracy: 0.9779 - val_loss: 0.0720
# Epoch 6/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9884 - loss: 0.0404 - val_accuracy: 0.9773 - val_loss: 0.0731
# Epoch 7/50
# 469/469 - 11s - 22ms/step - accuracy: 0.9913 - loss: 0.0311 - val_accuracy: 0.9798 - val_loss: 0.0650
# Epoch 8/50
# 469/469 - 11s - 24ms/step - accuracy: 0.9939 - loss: 0.0229 - val_accuracy: 0.9770 - val_loss: 0.0713
# Epoch 9/50
# 469/469 - 11s - 24ms/step - accuracy: 0.9952 - loss: 0.0184 - val_accuracy: 0.9801 - val_loss: 0.0658
# Epoch 10/50
# 469/469 - 12s - 25ms/step - accuracy: 0.9968 - loss: 0.0132 - val_accuracy: 0.9808 - val_loss: 0.0640
# Epoch 11/50
# 469/469 - 12s - 26ms/step - accuracy: 0.9979 - loss: 0.0100 - val_accuracy: 0.9811 - val_loss: 0.0657
# Epoch 12/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9980 - loss: 0.0080 - val_accuracy: 0.9809 - val_loss: 0.0695
# Epoch 13/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9819 - val_loss: 0.0653
# Epoch 14/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9985 - loss: 0.0066 - val_accuracy: 0.9813 - val_loss: 0.0728
# Epoch 15/50
# 469/469 - 11s - 23ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9786 - val_loss: 0.0845
# Epoch 16/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9993 - loss: 0.0037 - val_accuracy: 0.9806 - val_loss: 0.0726
# Epoch 17/50
# 469/469 - 11s - 22ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9812 - val_loss: 0.0776
# Epoch 18/50
# 469/469 - 11s - 24ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9817 - val_loss: 0.0736
# Epoch 19/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9789 - val_loss: 0.0913
# Epoch 20/50
# 469/469 - 10s - 21ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.9810 - val_loss: 0.0815
# Epoch 21/50
# 469/469 - 10s - 21ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9826 - val_loss: 0.0768
# Epoch 22/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9999 - loss: 5.1865e-04 - val_accuracy: 0.9833 - val_loss: 0.0766
# Epoch 23/50
# 469/469 - 10s - 21ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9703 - val_loss: 0.1401
# Epoch 24/50
# 469/469 - 9s - 19ms/step - accuracy: 0.9971 - loss: 0.0085 - val_accuracy: 0.9805 - val_loss: 0.0861
# Epoch 25/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9814 - val_loss: 0.0816
# Epoch 26/50
# 469/469 - 10s - 22ms/step - accuracy: 0.9999 - loss: 5.7864e-04 - val_accuracy: 0.9827 - val_loss: 0.0790
# Epoch 27/50
# 469/469 - 11s - 24ms/step - accuracy: 1.0000 - loss: 2.9528e-04 - val_accuracy: 0.9834 - val_loss: 0.0788
# Epoch 28/50
# 469/469 - 10s - 22ms/step - accuracy: 1.0000 - loss: 1.2355e-04 - val_accuracy: 0.9835 - val_loss: 0.0806
# Epoch 29/50
# 469/469 - 11s - 23ms/step - accuracy: 1.0000 - loss: 9.0112e-05 - val_accuracy: 0.9834 - val_loss: 0.0818
# Epoch 30/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 7.1338e-05 - val_accuracy: 0.9833 - val_loss: 0.0835
# Epoch 31/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 5.7030e-05 - val_accuracy: 0.9833 - val_loss: 0.0848
# Epoch 32/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 4.7457e-05 - val_accuracy: 0.9836 - val_loss: 0.0851
# Epoch 33/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 3.8813e-05 - val_accuracy: 0.9836 - val_loss: 0.0872
# Epoch 34/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 3.2121e-05 - val_accuracy: 0.9837 - val_loss: 0.0881
# Epoch 35/50
# 469/469 - 10s - 20ms/step - accuracy: 1.0000 - loss: 2.6131e-05 - val_accuracy: 0.9834 - val_loss: 0.0891
# Epoch 36/50
# 469/469 - 9s - 20ms/step - accuracy: 1.0000 - loss: 2.1784e-05 - val_accuracy: 0.9827 - val_loss: 0.0917
# Epoch 37/50
# 469/469 - 9s - 20ms/step - accuracy: 1.0000 - loss: 1.9198e-05 - val_accuracy: 0.9833 - val_loss: 0.0928
# Epoch 38/50
# 469/469 - 9s - 20ms/step - accuracy: 1.0000 - loss: 1.8576e-05 - val_accuracy: 0.9836 - val_loss: 0.0958
# Epoch 39/50
# 469/469 - 9s - 19ms/step - accuracy: 0.9958 - loss: 0.0156 - val_accuracy: 0.9820 - val_loss: 0.0808
# Epoch 40/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9821 - val_loss: 0.0801
# Epoch 41/50
# 469/469 - 10s - 22ms/step - accuracy: 1.0000 - loss: 2.9446e-04 - val_accuracy: 0.9836 - val_loss: 0.0785
# Epoch 42/50
# 469/469 - 10s - 22ms/step - accuracy: 1.0000 - loss: 1.1852e-04 - val_accuracy: 0.9839 - val_loss: 0.0800
# Epoch 43/50
# 469/469 - 11s - 24ms/step - accuracy: 1.0000 - loss: 8.3027e-05 - val_accuracy: 0.9839 - val_loss: 0.0818
# Epoch 44/50
# 469/469 - 10s - 22ms/step - accuracy: 1.0000 - loss: 6.2569e-05 - val_accuracy: 0.9842 - val_loss: 0.0831
# Epoch 45/50
# 469/469 - 10s - 22ms/step - accuracy: 1.0000 - loss: 4.8408e-05 - val_accuracy: 0.9841 - val_loss: 0.0847
# Epoch 46/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 3.7789e-05 - val_accuracy: 0.9840 - val_loss: 0.0863
# Epoch 47/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 2.9861e-05 - val_accuracy: 0.9840 - val_loss: 0.0876
# Epoch 48/50
# 469/469 - 11s - 23ms/step - accuracy: 1.0000 - loss: 2.3973e-05 - val_accuracy: 0.9840 - val_loss: 0.0889
# Epoch 49/50
# 469/469 - 10s - 21ms/step - accuracy: 1.0000 - loss: 1.9120e-05 - val_accuracy: 0.9842 - val_loss: 0.0904
# Epoch 50/50
# 469/469 - 10s - 22ms/step - accuracy: 1.0000 - loss: 1.5473e-05 - val_accuracy: 0.9841 - val_loss: 0.0921

# %%
# 예측(성능 측정)
print("정확률=", dmlp.evaluate(x_test, y_test, verbose=0)[1]*100)
# Out:
# 정확률= 98.40999841690063

# %%
# 모델 저장
dmlp.save("dmlp_trained.h5") # 비전 에이전트 제작을 위해 학습된 모델을 저장
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# 정확도 그래프 그리기
plt.plot(hist.history["accuracy"])
plt.plot(hist.history["val_accuracy"])
plt.title("Accuracy graph")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend(["train", "test"])
plt.grid()
plt.show()

# %%
# 정확도 그래프 그리기
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"])
plt.title("Loss graph")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(["train", "test"])
plt.grid()
plt.show()
